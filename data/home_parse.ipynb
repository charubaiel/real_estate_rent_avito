# %%
import pandas as pd
import time
from tqdm import tqdm
import numpy as np

# %%
base_url = 'https://dom.mingkh.ru'

# %%
for page in tqdm(range(1,328)):
    time.sleep(np.random.poisson(5))
    page_table = pd.read_html(f'https://dom.mingkh.ru/moskva/moskva/houses?page={page}',extract_links='body')[0]
    page_table[['Адрес','home_url']] = page_table['Адрес'].apply('|'.join).str.split('|',expand=True)
    page_table.assign(page=page).to_csv('base_home_data.csv',mode='a')

# %%
dd = pd.read_csv('base_home_data.csv')

# %%
def parse_home_page(home_url,id):
    df_list = pd.read_html(home_url)
    home_data = pd.concat(df_list,axis=0)\
                    .iloc[:,:3].dropna(thresh=1)\
                        .drop_duplicates(subset=0)\
                            .set_index(0).fillna('')\
                                .astype(str).apply(''.join,axis=1)\
                                    .rename(id)
    return home_data.rename_axis('id').to_frame().T

# %%
import httpx
import asyncio
from io import BytesIO
from tqdm import tqdm

# %%
dd.shape
# Out:
# (32933, 9)

# %%
home_list = dd['home_url'].where(lambda x: x!='home_url').dropna().drop_duplicates()

# %%
result_list = []
for idx,url in tqdm(enumerate(home_list,1),total=len(home_list)):
    result_list.append(parse_home_page(base_url+url,url.split('/')[-1]))
    if idx % 500 ==0:
        pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
        result_list = []
# Out:
#   2%|▏         | 499/32551 [02:36<3:01:23,  2.95it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество лифтов', 'Количество подъездов',
#        'Наибольшее количество этажей', 'Наименьшее количество этажей',
#        'Количество нежилых помещений', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Площадь помещений общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка',
#        'Формирование фонда кап. ремонта', 'Тип дома', 'Износ здания, %',
#        'Состояние дома', 'Класс энергоэффективности',
#        'Количество вводов в дом, ед.', 'Вентиляция', 'Водоотведение',
#        'Система водостоков', 'Газоснабжение', 'Горячее водоснабжение',
#        'Система пожаротушения', 'Теплоснабжение', 'Холодное водоснабжение',
#        'Электроснабжение', 'Количество мусоропроводов, ед.', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Внутренние стены', 'Тип внутренних стен',
#        'Физический износ', 'Тип перекрытия', 'Крыша', 'Форма крыши',
#        'Материал фундамента', 'Фасад', 'Тип наружных стен',
#        'Материал отделки фасада',
#        'Год проведения последнего капитального ремонта', 'Окна',
#        'Материал окон', 'Тип наружного утепления фасада',
#        'Площадь зем. участка общего имущества м2', 'Площадь парковки м2',
#        'Двери', 'Отделочные покрытия помещений общего пользования',
#        'Площадь отмостки', 'Утепляющие слои чердачных перекрытий',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Дата установления класса энергоэффективности'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#   3%|▎         | 999/32551 [05:06<2:27:09,  3.57it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '1000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество лифтов', 'Количество подъездов',
#        'Наибольшее количество этажей', 'Наименьшее количество этажей',
#        'Количество нежилых помещений', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Площадь помещений общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка',
#        'Формирование фонда кап. ремонта', 'Тип дома', 'Износ здания, %',
#        'Состояние дома', 'Количество вводов в дом, ед.', 'Вентиляция',
#        'Водоотведение', 'Система водостоков', 'Газоснабжение',
#        'Горячее водоснабжение', 'Система пожаротушения', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Материал фундамента', 'Площадь отмостки',
#        'Физический износ', 'Внутренние стены', 'Тип внутренних стен', 'Фасад',
#        'Тип наружных стен', 'Тип наружного утепления фасада',
#        'Материал отделки фасада', 'Крыша', 'Форма крыши',
#        'Утепляющие слои чердачных перекрытий', 'Окна', 'Материал окон',
#        'Двери', 'Отделочные покрытия помещений общего пользования',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Площадь зем. участка общего имущества м2', 'Площадь парковки м2',
#        'Класс энергоэффективности', 'Количество мусоропроводов, ед.',
#        'Тип перекрытия', 'Год проведения последнего капитального ремонта',
#        'Дата установления класса энергоэффективности'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#   5%|▍         | 1499/32551 [07:34<2:33:13,  3.38it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '1500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество подъездов', 'Наибольшее количество этажей',
#        'Наименьшее количество этажей', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Площадь помещений общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка',
#        'Формирование фонда кап. ремонта', 'Тип дома', 'Износ здания, %',
#        'Состояние дома', 'Количество вводов в дом, ед.', 'Вентиляция',
#        'Водоотведение', 'Система водостоков', 'Газоснабжение',
#        'Горячее водоснабжение', 'Система пожаротушения', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Внутренние стены', 'Тип внутренних стен', 'Фасад', 'Тип наружных стен',
#        'Количество лифтов', 'Тип фундамента', 'Материал фундамента',
#        'Площадь отмостки', 'Физический износ',
#        'Тип наружного утепления фасада', 'Материал отделки фасада', 'Крыша',
#        'Форма крыши', 'Утепляющие слои чердачных перекрытий', 'Окна',
#        'Материал окон', 'Двери',
#        'Отделочные покрытия помещений общего пользования',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Отопительные приборы',
#        'Тип отопительных приборов', 'Количество нежилых помещений',
#        'Количество мусоропроводов, ед.', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Запорная арматура системы холодного водоснабжения', 'Тип перекрытия',
#        'Площадь зем. участка общего имущества м2', 'Класс энергоэффективности',
#        'Дата установления класса энергоэффективности',
#        'Год проведения последнего капитального ремонта',
#        'Площадь парковки м2'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#   6%|▌         | 1999/32551 [10:02<2:25:23,  3.50it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '2000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество лифтов', 'Количество подъездов',
#        'Наибольшее количество этажей', 'Наименьшее количество этажей',
#        'Количество нежилых помещений', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Серия, тип постройки здания',
#        'Спортивная площадка', 'Формирование фонда кап. ремонта', 'Тип дома',
#        'Износ здания, %', 'Состояние дома', 'Количество вводов в дом, ед.',
#        'Вентиляция', 'Водоотведение', 'Система водостоков', 'Газоснабжение',
#        'Горячее водоснабжение', 'Система пожаротушения', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение',
#        'Количество мусоропроводов, ед.', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Материал фундамента', 'Физический износ',
#        'Внутренние стены', 'Тип внутренних стен', 'Фасад', 'Тип наружных стен',
#        'Тип наружного утепления фасада', 'Материал отделки фасада', 'Окна',
#        'Материал окон', 'Двери',
#        'Отделочные покрытия помещений общего пользования',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Площадь помещений общего имущества м2', 'Тип перекрытия', 'Крыша',
#        'Форма крыши', 'Утепляющие слои чердачных перекрытий',
#        'Площадь отмостки', 'Площадь зем. участка общего имущества м2',
#        'Площадь парковки м2', 'Год проведения последнего капитального ремонта',
#        'Класс энергоэффективности',
#        'Дата установления класса энергоэффективности'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#   8%|▊         | 2499/32551 [12:38<2:23:45,  3.48it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '2500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index([                                     'Год ввода в эксплуатацию',
#                                                     'Детская площадка',
#                                                'Дом признан аварийным',
#                                           'Количество жилых помещений',
#                                                    'Количество лифтов',
#                                                 'Количество подъездов',
#                                         'Наибольшее количество этажей',
#                                         'Количество нежилых помещений',
#                                           'Площадь жилых помещений м2',
#                                         'Площадь нежилых помещений м2',
#                                          'Серия, тип постройки здания',
#                                                  'Спортивная площадка',
#                                                             'Тип дома',
#                                                       'Состояние дома',
#                                            'Класс энергоэффективности',
#                                                            'Фундамент',
#                                                       'Тип фундамента',
#                                                  'Материал фундамента',
#                                                     'Физический износ',
#                                                     'Внутренние стены',
#                                                  'Тип внутренних стен',
#                                                                'Фасад',
#                                                    'Тип наружных стен',
#                                       'Тип наружного утепления фасада',
#                                              'Материал отделки фасада',
#                                                           'Перекрытия',
#                                                       'Тип перекрытия',
#                                                                'Крыша',
#                                                          'Форма крыши',
#                                                                 'Окна',
#                                                        'Материал окон',
#                                 'Сеть внутридомовой системы отопления',
#                                                        'Материал сети',
#                                          'Материал теплоизоляции сети',
#                                             'Стояки системы отопления',
#            'Тип поквартирной разводки внутридомовой системы отопления',
#                                                             'Материал',
#                                  'Запорная арматура системы отопления',
#                                                 'Отопительные приборы',
#                                            'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#                               'Стояки системы холодного водоснабжения',
#                    'Запорная арматура системы холодного водоснабжения',
#         'Сеть внутридомовой инженерной системы горячего водоснабжения',
#                                'Стояки системы горячего водоснабжения',
#                     'Запорная арматура системы горячего водоснабжения',
#                                 'Утепляющие слои чердачных перекрытий',
#                                                     'Площадь отмостки',
#                                   'Класс энергетической эффективности',
#                                         'Наименьшее количество этажей',
#                                'Площадь помещений общего имущества м2',
#                                      'Формирование фонда кап. ремонта',
#                                                      'Износ здания, %',
#                                         'Количество вводов в дом, ед.',
#                                                           'Вентиляция',
#                                                        'Водоотведение',
#                                                   'Система водостоков',
#                                                        'Газоснабжение',
#                                                'Горячее водоснабжение',
#                                                'Система пожаротушения',
#                                                       'Теплоснабжение',
#                                               'Холодное водоснабжение',
#                                                     'Электроснабжение',
#                                       'Количество мусоропроводов, ед.',
#                                                        'Несущие стены',
#                                                'Площадь подвала, кв.м',
#                                                         'Мусоропровод',
#                             'Площадь зем. участка общего имущества м2',
#                                                  'Площадь парковки м2',
#                       'Год проведения последнего капитального ремонта',
#                                                                'Двери',
#                     'Отделочные покрытия помещений общего пользования',
#                         'Дата установления класса энергоэффективности',
#                                                                    nan],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_items] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#   9%|▉         | 2999/32551 [15:17<2:30:31,  3.27it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '3000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index([                                     'Год ввода в эксплуатацию',
#                                                     'Детская площадка',
#                                                'Дом признан аварийным',
#                                           'Количество жилых помещений',
#                                   'Класс энергетической эффективности',
#                                                 'Количество подъездов',
#                                         'Наибольшее количество этажей',
#                                         'Наименьшее количество этажей',
#                                           'Площадь жилых помещений м2',
#                                'Площадь помещений общего имущества м2',
#                                          'Серия, тип постройки здания',
#                                                  'Спортивная площадка',
#                                      'Формирование фонда кап. ремонта',
#                                                             'Тип дома',
#                                                      'Износ здания, %',
#                                                       'Состояние дома',
#                                         'Количество вводов в дом, ед.',
#                                                           'Вентиляция',
#                                                        'Водоотведение',
#                                                   'Система водостоков',
#                                                        'Газоснабжение',
#                                                'Горячее водоснабжение',
#                                                'Система пожаротушения',
#                                                       'Теплоснабжение',
#                                               'Холодное водоснабжение',
#                                                     'Электроснабжение',
#                                                        'Несущие стены',
#                                                'Площадь подвала, кв.м',
#                                                         'Мусоропровод',
#                                                           'Перекрытия',
#                                                            'Фундамент',
#                                                       'Тип фундамента',
#                                                  'Материал фундамента',
#                                                     'Площадь отмостки',
#                                                     'Физический износ',
#                                                     'Внутренние стены',
#                                                  'Тип внутренних стен',
#                                                                'Фасад',
#                                                    'Тип наружных стен',
#                                       'Тип наружного утепления фасада',
#                                              'Материал отделки фасада',
#                                                       'Тип перекрытия',
#                                                                'Крыша',
#                                                          'Форма крыши',
#                                 'Утепляющие слои чердачных перекрытий',
#                                                                 'Окна',
#                                                        'Материал окон',
#                                                                'Двери',
#                     'Отделочные покрытия помещений общего пользования',
#                                 'Сеть внутридомовой системы отопления',
#                                                        'Материал сети',
#                                          'Материал теплоизоляции сети',
#                                  'Запорная арматура системы отопления',
#                       'Год проведения последнего капитального ремонта',
#                                             'Стояки системы отопления',
#            'Тип поквартирной разводки внутридомовой системы отопления',
#                                                             'Материал',
#                                                 'Отопительные приборы',
#                                            'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#                               'Стояки системы холодного водоснабжения',
#                    'Запорная арматура системы холодного водоснабжения',
#         'Сеть внутридомовой инженерной системы горячего водоснабжения',
#                                'Стояки системы горячего водоснабжения',
#                     'Запорная арматура системы горячего водоснабжения',
#                                         'Площадь нежилых помещений м2',
#                                                    'Количество лифтов',
#                                         'Количество нежилых помещений',
#                             'Площадь зем. участка общего имущества м2',
#                                       'Количество мусоропроводов, ед.',
#                                                  'Площадь парковки м2',
#                                            'Класс энергоэффективности',
#                         'Дата установления класса энергоэффективности',
#                                                                    nan],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_items] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  11%|█         | 3499/32551 [17:51<2:23:12,  3.38it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '3500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество лифтов', 'Количество подъездов',
#        'Наибольшее количество этажей', 'Наименьшее количество этажей',
#        'Количество нежилых помещений', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Площадь помещений общего имущества м2',
#        'Площадь зем. участка общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка',
#        'Формирование фонда кап. ремонта', 'Тип дома', 'Износ здания, %',
#        'Состояние дома', 'Количество вводов в дом, ед.', 'Вентиляция',
#        'Водоотведение', 'Система водостоков', 'Газоснабжение',
#        'Горячее водоснабжение', 'Система пожаротушения', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение',
#        'Количество мусоропроводов, ед.', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Материал фундамента', 'Площадь отмостки',
#        'Физический износ', 'Внутренние стены', 'Тип внутренних стен', 'Фасад',
#        'Тип наружных стен', 'Тип наружного утепления фасада',
#        'Материал отделки фасада', 'Тип перекрытия', 'Крыша', 'Форма крыши',
#        'Утепляющие слои чердачных перекрытий', 'Окна', 'Материал окон',
#        'Двери', 'Отделочные покрытия помещений общего пользования',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Класс энергоэффективности',
#        'Год проведения последнего капитального ремонта', 'Площадь парковки м2',
#        'Дата установления класса энергоэффективности'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  12%|█▏        | 3999/32551 [20:21<4:11:30,  1.89it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '4000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index([                                     'Год ввода в эксплуатацию',
#                                                     'Детская площадка',
#                                                'Дом признан аварийным',
#                                           'Количество жилых помещений',
#                                   'Класс энергетической эффективности',
#                                                    'Количество лифтов',
#                                                 'Количество подъездов',
#                                         'Наибольшее количество этажей',
#                                         'Наименьшее количество этажей',
#                                         'Количество нежилых помещений',
#                                           'Площадь жилых помещений м2',
#                                         'Площадь нежилых помещений м2',
#                                'Площадь помещений общего имущества м2',
#                                          'Серия, тип постройки здания',
#                                                  'Спортивная площадка',
#                                      'Формирование фонда кап. ремонта',
#                                                             'Тип дома',
#                                                      'Износ здания, %',
#                                                       'Состояние дома',
#                                            'Класс энергоэффективности',
#                         'Дата установления класса энергоэффективности',
#                                         'Количество вводов в дом, ед.',
#                                                           'Вентиляция',
#                                                        'Водоотведение',
#                                                   'Система водостоков',
#                                                        'Газоснабжение',
#                                                'Горячее водоснабжение',
#                                                'Система пожаротушения',
#                                                       'Теплоснабжение',
#                                               'Холодное водоснабжение',
#                                                     'Электроснабжение',
#                                       'Количество мусоропроводов, ед.',
#                                                        'Несущие стены',
#                                                'Площадь подвала, кв.м',
#                                                         'Мусоропровод',
#                                                           'Перекрытия',
#                                                            'Фундамент',
#                                                       'Тип фундамента',
#                                                  'Материал фундамента',
#                                                     'Площадь отмостки',
#                                                     'Физический износ',
#                                                     'Внутренние стены',
#                                                  'Тип внутренних стен',
#                                                                'Фасад',
#                                                    'Тип наружных стен',
#                                       'Тип наружного утепления фасада',
#                                              'Материал отделки фасада',
#                                                                'Крыша',
#                                                          'Форма крыши',
#                                 'Утепляющие слои чердачных перекрытий',
#                                                                 'Окна',
#                                                        'Материал окон',
#                                                                'Двери',
#                     'Отделочные покрытия помещений общего пользования',
#                                 'Сеть внутридомовой системы отопления',
#                                                        'Материал сети',
#                                          'Материал теплоизоляции сети',
#                                             'Стояки системы отопления',
#            'Тип поквартирной разводки внутридомовой системы отопления',
#                                                             'Материал',
#                                  'Запорная арматура системы отопления',
#                                                 'Отопительные приборы',
#                                            'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#                               'Стояки системы холодного водоснабжения',
#                    'Запорная арматура системы холодного водоснабжения',
#         'Сеть внутридомовой инженерной системы горячего водоснабжения',
#                                'Стояки системы горячего водоснабжения',
#                     'Запорная арматура системы горячего водоснабжения',
#                             'Площадь зем. участка общего имущества м2',
#                                                  'Площадь парковки м2',
#                                                       'Тип перекрытия',
#                       'Год проведения последнего капитального ремонта',
#                                                                    nan],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_items] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  14%|█▍        | 4499/32551 [23:04<2:19:24,  3.35it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '4500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество подъездов', 'Наибольшее количество этажей',
#        'Наименьшее количество этажей', 'Количество нежилых помещений',
#        'Площадь жилых помещений м2', 'Площадь нежилых помещений м2',
#        'Площадь помещений общего имущества м2', 'Серия, тип постройки здания',
#        'Спортивная площадка', 'Формирование фонда кап. ремонта', 'Тип дома',
#        'Износ здания, %', 'Состояние дома', 'Количество вводов в дом, ед.',
#        'Вентиляция', 'Водоотведение', 'Система водостоков', 'Газоснабжение',
#        'Горячее водоснабжение', 'Система пожаротушения', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Материал фундамента', 'Площадь отмостки',
#        'Физический износ', 'Внутренние стены', 'Тип внутренних стен', 'Фасад',
#        'Тип наружных стен', 'Тип наружного утепления фасада',
#        'Материал отделки фасада',
#        'Год проведения последнего капитального ремонта', 'Тип перекрытия',
#        'Крыша', 'Форма крыши', 'Утепляющие слои чердачных перекрытий', 'Окна',
#        'Материал окон', 'Двери',
#        'Отделочные покрытия помещений общего пользования',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов', 'Количество лифтов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Площадь зем. участка общего имущества м2', 'Площадь парковки м2',
#        'Класс энергоэффективности',
#        'Дата установления класса энергоэффективности',
#        'Количество мусоропроводов, ед.'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  15%|█▌        | 4999/32551 [25:39<2:07:37,  3.60it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '5000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index([                                     'Год ввода в эксплуатацию',
#                                                     'Детская площадка',
#                                                'Дом признан аварийным',
#                                           'Количество жилых помещений',
#                                   'Класс энергетической эффективности',
#                                                    'Количество лифтов',
#                                                 'Количество подъездов',
#                                         'Наибольшее количество этажей',
#                                         'Наименьшее количество этажей',
#                                         'Количество нежилых помещений',
#                                           'Площадь жилых помещений м2',
#                                         'Площадь нежилых помещений м2',
#                                'Площадь помещений общего имущества м2',
#                                                  'Площадь парковки м2',
#                                          'Серия, тип постройки здания',
#                                                  'Спортивная площадка',
#                                      'Формирование фонда кап. ремонта',
#                                                             'Тип дома',
#                                                      'Износ здания, %',
#                                                       'Состояние дома',
#                                            'Класс энергоэффективности',
#                         'Дата установления класса энергоэффективности',
#                                         'Количество вводов в дом, ед.',
#                                                           'Вентиляция',
#                                                        'Водоотведение',
#                                                   'Система водостоков',
#                                                        'Газоснабжение',
#                                                'Горячее водоснабжение',
#                                                'Система пожаротушения',
#                                                       'Теплоснабжение',
#                                               'Холодное водоснабжение',
#                                                     'Электроснабжение',
#                                       'Количество мусоропроводов, ед.',
#                                                        'Несущие стены',
#                                                'Площадь подвала, кв.м',
#                                                         'Мусоропровод',
#                                                           'Перекрытия',
#                                                            'Фундамент',
#                                                       'Тип фундамента',
#                                                  'Материал фундамента',
#                                                     'Площадь отмостки',
#                                                     'Физический износ',
#                                                     'Внутренние стены',
#                                                  'Тип внутренних стен',
#                                                                'Фасад',
#                                                    'Тип наружных стен',
#                                       'Тип наружного утепления фасада',
#                                              'Материал отделки фасада',
#                       'Год проведения последнего капитального ремонта',
#                                                       'Тип перекрытия',
#                                                                'Крыша',
#                                                          'Форма крыши',
#                                 'Утепляющие слои чердачных перекрытий',
#                                                                 'Окна',
#                                                        'Материал окон',
#                                                                'Двери',
#                     'Отделочные покрытия помещений общего пользования',
#                                             'Стояки системы отопления',
#            'Тип поквартирной разводки внутридомовой системы отопления',
#                                                             'Материал',
#                                 'Сеть внутридомовой системы отопления',
#                                                        'Материал сети',
#                                          'Материал теплоизоляции сети',
#                                  'Запорная арматура системы отопления',
#                                                 'Отопительные приборы',
#                                            'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#                               'Стояки системы холодного водоснабжения',
#                    'Запорная арматура системы холодного водоснабжения',
#         'Сеть внутридомовой инженерной системы горячего водоснабжения',
#                                'Стояки системы горячего водоснабжения',
#                     'Запорная арматура системы горячего водоснабжения',
#                             'Площадь зем. участка общего имущества м2',
#                                                                    nan],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_items] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  17%|█▋        | 5499/32551 [28:16<2:25:49,  3.09it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '5500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Количество лифтов',
#        'Количество подъездов', 'Наибольшее количество этажей',
#        'Площадь жилых помещений м2', 'Площадь нежилых помещений м2',
#        'Площадь зем. участка общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка', 'Тип дома',
#        'Износ здания, %', 'Состояние дома', 'Количество мусоропроводов, ед.',
#        'Несущие стены', 'Площадь подвала, кв.м', 'Водоотведение',
#        'Газоснабжение', 'Горячее водоснабжение', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение', 'Внутренние стены',
#        'Тип внутренних стен', 'Фасад', 'Тип наружных стен', 'Крыша',
#        'Форма крыши', 'Класс энергетической эффективности',
#        'Наименьшее количество этажей', 'Количество нежилых помещений',
#        'Формирование фонда кап. ремонта', 'Класс энергоэффективности',
#        'Дата установления класса энергоэффективности',
#        'Количество вводов в дом, ед.', 'Вентиляция', 'Система водостоков',
#        'Система пожаротушения', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Тип наружного утепления фасада', 'Тип перекрытия',
#        'Площадь помещений общего имущества м2', 'Площадь парковки м2',
#        'Материал фундамента', 'Площадь отмостки', 'Физический износ',
#        'Материал отделки фасада',
#        'Год проведения последнего капитального ремонта',
#        'Утепляющие слои чердачных перекрытий', 'Окна', 'Материал окон',
#        'Двери', 'Отделочные покрытия помещений общего пользования',
#        'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Материал сети', 'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Материал теплоизоляции сети', 'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Сеть внутридомовой системы отопления'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  18%|█▊        | 5999/32551 [30:57<2:16:08,  3.25it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '6000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# ...
#        'Год проведения последнего капитального ремонта',
#        'Площадь зем. участка общего имущества м2', 'Площадь парковки м2',
#        'Класс энергоэффективности',
#        'Дата установления класса энергоэффективности'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  95%|█████████▌| 30999/32551 [2:42:37<07:46,  3.33it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '31000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество подъездов', 'Наибольшее количество этажей',
#        'Наименьшее количество этажей', 'Количество нежилых помещений',
#        'Площадь жилых помещений м2', 'Площадь нежилых помещений м2',
#        'Площадь помещений общего имущества м2',
#        'Площадь зем. участка общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка',
#        'Формирование фонда кап. ремонта', 'Тип дома', 'Износ здания, %',
#        'Состояние дома', 'Класс энергоэффективности',
#        'Дата установления класса энергоэффективности',
#        'Количество вводов в дом, ед.', 'Вентиляция', 'Водоотведение',
#        'Система водостоков', 'Газоснабжение', 'Горячее водоснабжение',
#        'Система пожаротушения', 'Теплоснабжение', 'Холодное водоснабжение',
#        'Электроснабжение', 'Несущие стены', 'Мусоропровод', 'Перекрытия',
#        'Фундамент', 'Тип фундамента', 'Материал фундамента',
#        'Площадь отмостки', 'Физический износ', 'Внутренние стены',
#        'Тип внутренних стен', 'Фасад', 'Тип наружных стен',
#        'Тип наружного утепления фасада', 'Материал отделки фасада',
#        'Год проведения последнего капитального ремонта', 'Тип перекрытия',
#        'Крыша', 'Форма крыши', 'Утепляющие слои чердачных перекрытий', 'Окна',
#        'Материал окон', 'Двери',
#        'Отделочные покрытия помещений общего пользования',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения', 'Количество лифтов',
#        'Площадь парковки м2', 'Количество мусоропроводов, ед.',
#        'Площадь подвала, кв.м'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  97%|█████████▋| 31499/32551 [2:45:07<05:01,  3.49it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '31500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество лифтов', 'Количество подъездов',
#        'Наибольшее количество этажей', 'Наименьшее количество этажей',
#        'Количество нежилых помещений', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Серия, тип постройки здания',
#        'Спортивная площадка', 'Формирование фонда кап. ремонта', 'Тип дома',
#        'Износ здания, %', 'Состояние дома', 'Количество вводов в дом, ед.',
#        'Вентиляция', 'Водоотведение', 'Система водостоков', 'Газоснабжение',
#        'Горячее водоснабжение', 'Система пожаротушения', 'Теплоснабжение',
#        'Холодное водоснабжение', 'Электроснабжение',
#        'Количество мусоропроводов, ед.', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Материал фундамента', 'Площадь отмостки',
#        'Физический износ', 'Год проведения последнего капитального ремонта',
#        'Внутренние стены', 'Тип внутренних стен', 'Фасад', 'Тип наружных стен',
#        'Тип наружного утепления фасада', 'Материал отделки фасада',
#        'Тип перекрытия', 'Крыша', 'Форма крыши',
#        'Утепляющие слои чердачных перекрытий', 'Окна', 'Материал окон',
#        'Двери', 'Отделочные покрытия помещений общего пользования',
#        'Площадь помещений общего имущества м2', 'Класс энергоэффективности',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Запорная арматура системы отопления', 'Отопительные приборы',
#        'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Запорная арматура системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Дата установления класса энергоэффективности', 'Площадь парковки м2',
#        'Площадь зем. участка общего имущества м2'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
#  98%|█████████▊| 31999/32551 [2:47:42<02:38,  3.49it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '32000'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Год ввода в эксплуатацию', 'Детская площадка', 'Дом признан аварийным',
#        'Количество жилых помещений', 'Класс энергетической эффективности',
#        'Количество лифтов', 'Количество подъездов',
#        'Наибольшее количество этажей', 'Наименьшее количество этажей',
#        'Количество нежилых помещений', 'Площадь жилых помещений м2',
#        'Площадь нежилых помещений м2', 'Площадь помещений общего имущества м2',
#        'Серия, тип постройки здания', 'Спортивная площадка',
#        'Формирование фонда кап. ремонта', 'Тип дома', 'Состояние дома',
#        'Количество вводов в дом, ед.', 'Вентиляция', 'Водоотведение',
#        'Система водостоков', 'Газоснабжение', 'Горячее водоснабжение',
#        'Система пожаротушения', 'Теплоснабжение', 'Холодное водоснабжение',
#        'Электроснабжение', 'Количество мусоропроводов, ед.', 'Несущие стены',
#        'Площадь подвала, кв.м', 'Мусоропровод', 'Перекрытия', 'Фундамент',
#        'Тип фундамента', 'Материал фундамента', 'Площадь отмостки',
#        'Внутренние стены', 'Тип внутренних стен', 'Фасад', 'Тип наружных стен',
#        'Тип наружного утепления фасада', 'Материал отделки фасада',
#        'Тип перекрытия', 'Крыша', 'Форма крыши',
#        'Утепляющие слои чердачных перекрытий', 'Окна', 'Материал окон',
#        'Сеть внутридомовой системы отопления', 'Материал сети',
#        'Материал теплоизоляции сети', 'Стояки системы отопления',
#        'Тип поквартирной разводки внутридомовой системы отопления', 'Материал',
#        'Отопительные приборы', 'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#        'Стояки системы холодного водоснабжения',
#        'Сеть внутридомовой инженерной системы горячего водоснабжения',
#        'Стояки системы горячего водоснабжения', 'Износ здания, %',
#        'Физический износ', 'Год проведения последнего капитального ремонта',
#        'Двери', 'Отделочные покрытия помещений общего пользования',
#        'Запорная арматура системы холодного водоснабжения',
#        'Запорная арматура системы горячего водоснабжения',
#        'Запорная арматура системы отопления', 'Класс энергоэффективности',
#        'Площадь зем. участка общего имущества м2', 'Площадь парковки м2',
#        'Дата установления класса энергоэффективности'],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# 100%|█████████▉| 32499/32551 [2:50:14<00:15,  3.46it/s]/home/charubaiel/.local/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '32500'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index([                                     'Год ввода в эксплуатацию',
#                                                     'Детская площадка',
#                                                'Дом признан аварийным',
#                                           'Количество жилых помещений',
#                                                    'Количество лифтов',
#                                                 'Количество подъездов',
#                                         'Наибольшее количество этажей',
#                                         'Наименьшее количество этажей',
#                                           'Площадь жилых помещений м2',
#                                         'Площадь нежилых помещений м2',
#                                          'Серия, тип постройки здания',
#                                                  'Спортивная площадка',
#                                      'Формирование фонда кап. ремонта',
#                                                             'Тип дома',
#                                                      'Износ здания, %',
#                                                       'Состояние дома',
#                                         'Количество вводов в дом, ед.',
#                                                           'Вентиляция',
#                                                        'Водоотведение',
#                                                   'Система водостоков',
#                                                        'Газоснабжение',
#                                                'Горячее водоснабжение',
#                                                'Система пожаротушения',
#                                                       'Теплоснабжение',
#                                               'Холодное водоснабжение',
#                                                     'Электроснабжение',
#                                       'Количество мусоропроводов, ед.',
#                                                        'Несущие стены',
#                                                'Площадь подвала, кв.м',
#                                                         'Мусоропровод',
#                                                           'Перекрытия',
#                                                            'Фундамент',
#                                                       'Тип фундамента',
#                                                  'Материал фундамента',
#                                                     'Физический износ',
#                                                     'Внутренние стены',
#                                                  'Тип внутренних стен',
#                                                                'Фасад',
#                                                    'Тип наружных стен',
#                                       'Тип наружного утепления фасада',
#                                              'Материал отделки фасада',
#                                                       'Тип перекрытия',
#                                                                'Крыша',
#                                                          'Форма крыши',
#                                 'Утепляющие слои чердачных перекрытий',
#                                                                 'Окна',
#                                                        'Материал окон',
#                                                                'Двери',
#                     'Отделочные покрытия помещений общего пользования',
#                                   'Класс энергетической эффективности',
#                                         'Количество нежилых помещений',
#                                'Площадь помещений общего имущества м2',
#                                                     'Площадь отмостки',
#                                 'Сеть внутридомовой системы отопления',
#                                                        'Материал сети',
#                                          'Материал теплоизоляции сети',
#                                             'Стояки системы отопления',
#            'Тип поквартирной разводки внутридомовой системы отопления',
#                                                             'Материал',
#                                                 'Отопительные приборы',
#                                            'Тип отопительных приборов',
#        'Сеть внутридомовой инженерной системы холодного водоснабжения',
#                               'Стояки системы холодного водоснабжения',
#         'Сеть внутридомовой инженерной системы горячего водоснабжения',
#                                'Стояки системы горячего водоснабжения',
#                                  'Запорная арматура системы отопления',
#                    'Запорная арматура системы холодного водоснабжения',
#                     'Запорная арматура системы горячего водоснабжения',
#                       'Год проведения последнего капитального ремонта',
#                             'Площадь зем. участка общего имущества м2',
#                                                  'Площадь парковки м2',
#                                            'Класс энергоэффективности',
#                         'Дата установления класса энергоэффективности',
#                                                                    nan],
#       dtype='object', name='id')]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# /tmp/ipykernel_810/2103563321.py:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_items] [items->None]
#
#   pd.concat(result_list).to_hdf('detailed_data.h5',key=str(idx))
# 100%|██████████| 32551/32551 [2:50:32<00:00,  3.18it/s]

# %%
# async def get_url(session,url):
#     full_url = base_url + url       
#     response = await session.get(full_url)

#     if response.status_code == 200:
#         return response
#     print(response.status_code)

# async with httpx.AsyncClient(http2=True,timeout=30) as client:
#     tasks = []
#     for url in home_list.drop_duplicates().values:
#         tasks.append(get_url(client,url))

#     response_list = await asyncio.gather(*tasks,return_exceptions=True)
