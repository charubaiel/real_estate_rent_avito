# %%
import pandas as pd
import sqlite3

# %%
with sqlite3.connect('data/dagster_avito.db') as w:
    zz = pd.read_sql('select * from moskva_re',con=w)

# %%
zz
# Out:
#            date   publish_delta           id  \
# 0    2022-02-06  56 минут назад  i2211639585
# 1    2022-02-06     1 час назад  i2259778099
# 2    2022-02-06     1 час назад  i2308524040
# 3    2022-02-06    2 часа назад  i2289291210
# 4    2022-02-06    2 часа назад  i2299850069
# ..          ...             ...          ...
# 278  2022-02-06     2 дня назад  i2307541785
# 279  2022-02-06     2 дня назад  i2353155673
# 280  2022-02-06     2 дня назад  i2331910322
# 281  2022-02-06     2 дня назад  i2306567049
# 282  2022-02-06     2 дня назад  i2309580772
#
#                                                    url  \
# 0    /moskva/kvartiry/3-k._kvartira_92m_510et._2211...
# 1    /moskva/kvartiry/3-k._kvartira_80m_38et._22597...
# 2    /moskva/kvartiry/3-k._kvartira_94_m_2129_et._2...
# 3    /moskva/kvartiry/3-k._kvartira_94_m_28_et._228...
# 4    /moskva/kvartiry/3-k._kvartira_53m_78et._22998...
# ..                                                 ...
# ...
